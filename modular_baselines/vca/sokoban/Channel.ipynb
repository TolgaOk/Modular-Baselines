# %% [raw]
#   /$$$$$$  /$$   /$$  /$$$$$$  /$$   /$$ /$$   /$$ /$$$$$$$$ /$$
#  /$$__  $$| $$  | $$ /$$__  $$| $$$ | $$| $$$ | $$| $$_____/| $$
# | $$  \__/| $$  | $$| $$  \ $$| $$$$| $$| $$$$| $$| $$      | $$
# | $$      | $$$$$$$$| $$$$$$$$| $$ $$ $$| $$ $$ $$| $$$$$   | $$
# | $$      | $$__  $$| $$__  $$| $$  $$$$| $$  $$$$| $$__/   | $$
# | $$    $$| $$  | $$| $$  | $$| $$\  $$$| $$\  $$$| $$      | $$
# |  $$$$$$/| $$  | $$| $$  | $$| $$ \  $$| $$ \  $$| $$$$$$$$| $$$$$$$$
#  \______/ |__/  |__/|__/  |__/|__/  \__/|__/  \__/|________/|________/

# %%
# %load_ext autoreload
# %autoreload 2

import torch
import numpy as np
import matplotlib.pyplot as plt
import os
import json
import datetime
from collections import namedtuple

# %%
# !python run.py --log_interval 25 --grad_clip --entropy_coef 0.00025
# Out:
# /Users/tolga/anaconda/lib/python3.8/site-packages/pycolab/ascii_art.py:318: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   art = np.vstack(np.fromstring(line, dtype=np.uint8) for line in art)
# Logging to logs/01-31-2021-23-43-16/01-31-2021-23-43-16-772950/
# ---------------------------------
# | time/              |          |
# |    fps             | 196      |
# |    iterations      | 0        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 10       |
# | train/             |          |
# |    Transition MSE  | 756      |
# |    Transition loss | 0.796    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1       |
# | time/              |          |
# ...

# %%
import torch

x = torch.zeros(1, 64, 5, 5)
sum([k for k in x.split(16, dim=1)]).shape
# [k.shape for k in x.split(64//16, dim=1)]
# Out:
# torch.Size([1, 16, 5, 5])
