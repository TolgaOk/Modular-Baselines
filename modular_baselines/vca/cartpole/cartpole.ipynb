# %%
# !python run.py --n_repeat 1 --entropy_coef 0 --alpha 0
# Out:
# Logging to logs/01-30-2021-21-34-44/01-30-2021-21-34-44-926310/
# ---------------------------------
# | playback/          |          |
# |    action_grad     | 0.0178   |
# |    gate_mean       | 0.496    |
# |    gate_std        | 0.0223   |
# |    state_grad      | 0.0691   |
# | rollout/           |          |
# |    ep_len_mean     | 18.5     |
# |    ep_rew_mean     | 18.5     |
# | time/              |          |
# |    fps             | 1076     |
# |    iterations      | 0        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 50       |
# | train/             |          |
# |    E[R]            | -0.131   |
# |    Transition MSE  | 0.0839   |
# |    Transition loss | 758      |
# |    entropy         | 0.661    |
# |    log_probs       | -9.09    |
# ---------------------------------
# ---------------------------------
# | evaluation/        |          |
# |    reward          | 10       |
# | playback/          |          |
# ...

# %%
import gym

env = gym.make("CartPole-v1")

# %%
env.reset()
# Out:
# array([-0.03495324, -0.01326955, -0.03261029, -0.04648182])
